# %% [markdown]
# # 大二下大创及学习计划v2.2.1匹诺康尼
# （大家积极更新早日进入3.0须弥版本或者整理整理让它看起来更舒服）
#
# ## 一、大创
# ### 1.Linux相关
# 看点基础的东西直接上手就行，不会的问AI
# （要不谁上b站找找课？）
#
# 虚拟机……目前来看，这个暂时用不上，学习思路改为：
# 连接我们要用的服务器可以用git bash+ssh（询问戴鹏辉即可）
# 练习Linux可以去阿里云白嫖一个云主机即可，装Linux内核的ubantu
#
# 关于shell的问题：https://github.com/microsoft/terminal
#
# ### 2.关于ML与DL还有神经网络
# pytorch：【PyTorch深度学习快速入门教程（绝对通俗易懂！）【小土堆】】 https://www.bilibili.com/video/BV1hE411t7RN/?share_source=copy_web&vd_source=a0325e5753823a3867a5c919bb3016b3
# 笔记：https://mp.weixin.qq.com/s/d2vnpXMCSbO7qEET2PNN8g
#
# tensorflow：【【北京大学】Tensorflow2.0】 https://www.bilibili.com/video/BV1B7411L7Qt/?share_source=copy_web&vd_source=a0325e5753823a3867a5c919bb3016b3
#
# 吴恩达：【【斯坦福大学】CS229 机器学习 · 2018年（完结·中英字幕·机翻）】 https://www.bilibili.com/video/BV1JE411w7Ub/?share_source=copy_web
#
# GNN【【双语字幕】斯坦福CS224W《图机器学习》课程(2021) by Jure Leskovec】 https://www.bilibili.com/video/BV1RZ4y1c7Co/?share_source=copy_web
#
# ### 3.其它
# （1）相关学习资料
# 参考书籍：Python程序设计 陈春晖 翁恺 季江民
# 学习文档（菜鸟教程）：https://www.runoob.com/python3/python3-tutorial.html
# 其它书籍：
# 【超级会员V5】我通过百度网盘分享的文件：1.《白话机器学....pdf等3个文件
# 链接：https://pan.baidu.com/s/1wzEIJiOiRuveysfjnCszsw
# 提取码：7bW8
# 复制这段内容打开「百度网盘APP即可获取」
#
# （2）LaTex
# LaTeX新手教程：HYPERLINK https://zhuanlan.zhihu.com/p/456055339?utm_id=0 https://zhuanlan.zhihu.com/p/456055339?utm_id=0
# OverLeaf入门：HYPERLINK https://zhuanlan.zhihu.com/p/401596639?utm_id=0 https://zhuanlan.zhihu.com/p/401596639?utm_id=0
# Beamer入门：如何制作一份学术演讲PPT（Beamer）? - 江河的文章 - 知乎HYPERLINK https://zhuanlan.zhihu.com/p/355268035 https://zhuanlan.zhihu.com/p/355268035
# Another Beamer Theme Matrix
# https://mpetroff.net/files/beamer-theme-matrix/
# [Latex] Beamer 入门 - Deli的文章 - 知乎
# https://zhuanlan.zhihu.com/p/142023097
#
# ## 二、关于资料共享与多人协作
# ### 1.基于服务器与jupyter notebook代码等分享机制
# （1）服务器
# ！！！请不要把这个服务器传给其他人！！！
#
# 关于服务器的维护：大家上服务器时要是看见哪个不用的程序开着记得把它关掉，2核2G非常容易被干死机。
#
# 关于服务器上的Jupyter编程环境的全新应用：我发现可以上传文件和下载文件，其中pdf文件可以上传和下载；但是目前能可视化和使用的只有.ipynb文件，大家可以把写好的代码往上扔[旺柴]，用于效果展示
#
# 目前上面开展了几个项目：
# python学习及编程训练（有烤烤你第一期Test_You_1，可以把写好的传上去供大家参考）
# 实验用数据处理
# 其他作业编程
# 大创相关代码展示
#
# 其它无需多言。
#
# （2）jupyter notebook
# 倡议：涉及到编程相关的学习笔记、代码和想法都以notebook形式展示
# 可以参考：推动一种社区性、开源性的新学术交流（参考：https://mp.weixin.qq.com/s?__biz=MzIzMjQyNzQ5MA==&mid=2247487329&idx=1&sn=d877412b63527a150126302513a366ed&chksm=e89455ecdfe3dcfa020ed91077e0e880f552d6778654afe1569eb96ed43c8c61fa7860667d17&scene=21#wechat_redirect）
# 另：jupyter notebook可以导出为pdf和tex格式，但是不能含有中文；可以自行研究
#
# ### 2.GitHub建一个库和写一个手册
# 建立一个与大创相关的库，建议由戴鹏辉和黄罗琳帮助朱政鑫在他的账号上建这个库，名字你们可以想想，比如说叫RtawahistTreasure2024（手动狗头）
# https://www.liaoxuefeng.com/wiki/896043488029600/896827951938304
# git使用时遇到的问题及处理方法https://ohshitgit.com/zh
#
# 然后在上面放一个所有人都能编辑的类似于“开发指南（手册）”这种东西的大概可以称为大创日志的这样一个markdown文件（这玩意语法很简单，30min上手），用于记录我们大创各阶段的计划、实施方案和成功（手动狗头）
# For example，比如如何解决jupyter notebook的路径的方法就可以记录于其中
#
# ## 三、关于前半期的一些想法和规划
# ### 1.目前版本（v2.2.1）的规划
# 围绕那篇论文进行学习，于2023.3.22日晚交流学习成果。
#
# ### 2.细分：
# display方向：LaTex、beamer、最重要的是python作图即数据的可视化技术、以及一些论文中的作图技术
# 其中服务器上numerical_duff_solve提供了一个最基本的标准的用python中matplotlib库的作图范式
# https://realpython.com/python-matplotlib-guide/
# https://blog.datawrapper.de/colorguide/
# 【【莫烦Python】Matplotlib Python 画图教程】 https://www.bilibili.com/video/BV1Jx411L7LU/?p=19&share_source=copy_web&vd_source=a0325e5753823a3867a5c919bb3016b3
# 资源：https://mp.weixin.qq.com/s/cMMWnnSWozzNQvEmo6xF4Q
#
# develop方向：进行算法的研究与优化
# 李霄栋：https://www.jianguoyun.com/p/DSV5sSEQ4LbMBxiR6ZcFIAA
# 【【机器学习】【白板推导系列】【合集 1～33】】 https://www.bilibili.com/video/BV1aE411o7qd/?share_source=copy_web&vd_source=a0325e5753823a3867a5c919bb3016b3
# 笔记：https://www.yuque.com/bystander-wg876/yc5f72/pdv5ry
# 【02.神经元 - Python手搓神经网络】 https://www.bilibili.com/video/BV1f8411y7P4/?share_source=copy_web&vd_source=a0325e5753823a3867a5c919bb3016b3
# 【【官方双语】深度学习之神经网络的结构 Part 1 ver 2.0】 https://www.bilibili.com/video/BV1bx411M7Zx/?share_source=copy_web&vd_source=a0325e5753823a3867a5c919bb3016b3
#
# program方向：算法实现以及写代码调试等
#
# data方向：数据清理
# 【北理-Python数据分析与展示-Numpy、Matplotlib、Pandas】 https://www.bilibili.com/video/BV1L64y1X7om/?p=3&share_source=copy_web&vd_source=a0325e5753823a3867a5c919bb3016b3
#
# ## 四、学习资料整理
# 这部分主要用于存放大家搜集到的各种专业课资料。

# %% [markdown]
# # 小更新
#
# ## 2024.3.16
# 深度学习领域的圣经：https://github.com/exacity/deeplearningbook-chinese
#
# ## 2024.3.18
# 一个学习攻略：
# https://www.zhihu.com/question/26006703?utm_id=0
